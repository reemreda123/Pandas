# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\lenovo\Downloads\Salaries.csv")
#pd.read_excel('')

# %%
df=data.copy()

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
df.drop(['Notes','Status'],inplace=True,axis=1)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df['Agency'].unique()
# Out:
# array(['San Francisco'], dtype=object)

# %%
df.drop(['Id'],inplace=True,axis=1)

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)

# %%
df.Year.value_counts()
# Out:
# 2014    38120
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
df.Year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               606
# OvertimePay             1
# OtherPay                1
# Benefits            36160
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
df[df['OtherPay'].isnull()].index.tolist()
# Out:
# [148646]

# %%
df.drop([148646],inplace=True,axis=0)

# %%
df.reset_index(drop=True , inplace=True) #by3ml shift lel cells b3d el delete

# %%
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148646     Joann Anderson                     Communications Dispatcher 2
# 148647        Leon Walker                                       Custodian
# 148648      Roy I Tillery                                       Custodian
# 148649          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448841    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148650.000000     148650.000000  148650.000000
# mean    74770.333901      93695.075969    2012.522603
# std     50516.196009      62792.497391       1.117526
# min      -618.130000       -618.130000    2011.000000
# 25%     36169.955000      44073.337500    2012.000000
# ...

# %%
df.shape
# Out:
# (148650, 10)

# %%
df.isna().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
df[df['BasePay'].isna()]
# Out:
#              EmployeeName                   JobTitle  BasePay  OvertimePay  \
# 81391     Kevin P Cashman             Deputy Chief 3      NaN          0.0
# 84506   Demetrya  Mullens  Licensed Vocational Nurse      NaN          0.0
# 84960     Michael M Horan        Park Patrol Officer      NaN          0.0
# 90525        Thomas  Tang           Police Officer 3      NaN          0.0
# 90786      Michael C Hill             Deputy Sheriff      NaN          0.0
# ...                   ...                        ...      ...          ...
# 110526     Arthur L Curry    PS Aide Health Services      NaN          0.0
# 110527      Nereida  Vega               Senior Clerk      NaN          0.0
# 110528   Timothy E Gibson           Police Officer 3      NaN          0.0
# 110529     Mark E Laherty           Police Officer 3      NaN          0.0
# 110530      David P Kucia           Police Officer 3      NaN          0.0
#
# ...

# %%
df['BasePay']=df['BasePay'].fillna(0)

# %%
df.isna().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay                 0
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148650.000000  148650.000000  148650.000000  112491.000000
# mean    66055.506718    5066.059886    3648.767297   25007.893151
# std     42885.919334   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     32798.550000       0.000000       0.000000   11535.395000
# 50%     64862.310000       0.000000     811.270000   28628.620000
# 75%     94609.715000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148650.000000     148650.000000  148650.000000
# mean    74770.333901      93695.075969    2012.522603
# std     50516.196009      62792.497391       1.117526
# min      -618.130000       -618.130000    2011.000000
# 25%     36169.955000      44073.337500    2012.000000
# ...

# %%
df=pd.DataFrame(np.array([[1,2,3],[1,5,6],[6,6,7],[7,8,9]]),columns=['A','B','C'])

# %%
df['B']
# Out:
# 0    2
# 1    5
# 2    6
# 3    8
# Name: B, dtype: int32

# %%
df[['A','B']]
# Out:
#    A  B
# 0  1  2
# 1  1  5
# 2  6  6
# 3  7  8

# %%
df['A']+df['B']
# Out:
# 0     3
# 1     6
# 2    12
# 3    15
# dtype: int32

# %%
df['sum']=df['A']+df['B']

# %%
df
# Out:
#    A  B  C  sum
# 0  1  2  3    3
# 1  1  5  6    6
# 2  6  6  7   12
# 3  7  8  9   15

# %%
df.drop('B',axis=1, inplace=True)

# %%
df
# Out:
#    A  C  sum
# 0  1  3    3
# 1  1  6    6
# 2  6  7   12
# 3  7  9   15

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#    A  C  sum
# 1  1  6    6
# 2  6  7   12
# 3  7  9   15

# %%
df.iloc[1]
# Out:
# A       6
# C       7
# sum    12
# Name: 2, dtype: int32

# %%
df[df['A']>2]
# Out:
#    A  C  sum
# 2  6  7   12
# 3  7  9   15

# %%
df[df['A']>2]['A']
# Out:
# 2    6
# 3    7
# Name: A, dtype: int32

# %%
my_dict={'c1':[1,2,3,4,np.nan],'c2':['A','b','b','a','c'],'c3':['mo2men','aisha','abdallah','hasnaa','reem']}

# %%
my_dict
# Out:
# {'c1': [1, 2, 3, 4, nan],
#  'c2': ['A', 'b', 'b', 'a', 'c'],
#  'c3': ['mo2men', 'aisha', 'abdallah', 'hasnaa', 'reem']}

# %%
df=pd.DataFrame(my_dict)

# %%
df.head()
# Out:
#     c1 c2        c3
# 0  1.0  A    mo2men
# 1  2.0  b     aisha
# 2  3.0  b  abdallah
# 3  4.0  a    hasnaa
# 4  NaN  c      reem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      4 non-null      float64
#  1   c2      5 non-null      object
#  2   c3      5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df.dtypes
# Out:
# c1    float64
# c2     object
# c3     object
# dtype: object

# %%
df.isna()
# Out:
#       c1     c2     c3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4   True  False  False

# %%
df.isna().sum()
# Out:
# c1    1
# c2    0
# c3    0
# dtype: int64

# %%
df.describe()
# Out:
#              c1
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
def my_fun(x):
    return x*7-1

# %%
df['c1'].apply(my_fun) #haylf 3la kol element
# Out:
# 0     6.0
# 1    13.0
# 2    20.0
# 3    27.0
# 4     NaN
# Name: c1, dtype: float64
